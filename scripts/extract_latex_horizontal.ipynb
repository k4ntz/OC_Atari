# %%
import pandas as pd
import pickle
from termcolor import colored
import numpy as np

# %%
pkl_report_file = "../reports/all_games_report.pkl"
latex_report_file = "../reports/all_games_report.tex"
with open(pkl_report_file, "rb") as savefile:
    df = pickle.load(savefile)

# %%
df = df[~df.index.duplicated(keep='last')]
nb_games = len(df)
print(colored(f"{nb_games} out of 35 done !"))

# df.fillna("N/A", inplace=True)
dfT = df.T
# dfT["mean"] = dfT.mean(axis=1)
df = dfT.T

df = df.round(1)

dfT = dfT.drop(index=("C51"))

dfT["Scale (\%)"] = np.array([100, 85, 70, 57, 43, 28, 14, 0])
# Out:
# 41 out of 35 done !

# %%
dfT
# Out:
#                   Alien  Amidar  Assault  Asterix  Atlantis  BankHeist  \
# Random precision   51.4    75.8     95.4     93.1      96.3       87.9
#        recall      97.3    99.9     94.2     99.8      94.6       95.8
#        f-score     67.3    86.2     94.8     96.3      95.5       91.7
#        iou         97.7    97.0     95.3     96.0      95.8       87.3
# DQN    precision   51.2    86.3     97.1     95.0      96.6       96.2
#        recall      97.2    99.9     93.6     99.6      94.7       96.2
#        f-score     67.1    92.6     95.3     97.2      95.7       96.2
#        iou         97.4    92.4     93.8     96.1      95.0       94.7
#
#                   BattleZone  Berzerk  Bowling  Boxing  ...  RoadRunner  \
# Random precision        81.1     94.1     99.5    96.5  ...        95.5
#        recall           55.7     95.2     99.2    84.5  ...        97.5
#        f-score          66.0     94.6     99.3    90.1  ...        96.5
#        iou              95.1     78.4     99.6    93.5  ...        93.1
# DQN    precision        81.8     94.3     99.2    96.1  ...        85.2
#        recall           51.8     96.5     98.8    84.5  ...        78.7
#        f-score          63.4     95.4     99.0    89.9  ...        81.8
#        iou              93.5     77.4     99.4    93.4  ...        87.4
#
#                   Seaquest  Skiing  SpaceInvaders  Tennis  TimePilot  UpNDown  \
# Random precision      94.1    95.8           95.2    98.7       93.5     96.8
#        recall         87.9    96.5           98.7    99.9       94.7     99.1
#        f-score        90.9    96.2           96.9    99.3       94.1     97.9
#        iou            90.3    90.4           97.1    85.7       96.6     97.4
# DQN    precision      91.5    94.1           90.6    93.9       91.3     93.0
#        recall         81.3    94.2           95.9    98.7       94.3     97.7
#        f-score        86.1    94.2           93.1    96.2       92.8     95.3
#        iou            91.4    89.3           97.3    83.9       94.6     93.1
#
#                   Venture  VideoPinball  Scale (\%)
# Random precision     63.1          98.3         100
#        recall        99.9          94.6          85
#        f-score       77.4          96.4          70
#        iou           92.1          94.4          57
# DQN    precision     57.6          99.5          43
#        recall       100.0          95.3          28
#        f-score       73.1          97.3          14
#        iou           91.3          95.3           0
#
# [8 rows x 42 columns]

# %%
styler = dfT.style
styler.background_gradient(cmap='Spectral', vmin=0, vmax=100,)
styler.format(precision=1, na_rep="N/A")
styler.highlight_null("gray")
styler.map_index(
    lambda v: "rotatebox:{90}--rwrap--latex;", level=0, axis=1
)
styler.set_properties(**{'width': '3px'})
styler.format('', na_rep='MISS')  
ltx_code_o = styler.to_latex(
    caption=f"Statistiques on all games",
    clines="skip-last;data",
    convert_css=True,
    position_float="centering",
    hrules=True,
    multicol_align="c"
)

# %%
styler
# Out:
# <style type="text/css">
# #T_3fc13_row0_col0, #T_3fc13_row4_col0 {
#   background-color: #fcfeba;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row0_col1 {
#   background-color: #81cda5;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row0_col2, #T_3fc13_row0_col12, #T_3fc13_row0_col29, #T_3fc13_row0_col32, #T_3fc13_row2_col4, #T_3fc13_row2_col31, #T_3fc13_row3_col22, #T_3fc13_row3_col23, #T_3fc13_row4_col24, #T_3fc13_row6_col4, #T_3fc13_row6_col7, #T_3fc13_row6_col11, #T_3fc13_row6_col22, #T_3fc13_row6_col23, #T_3fc13_row7_col29 {
#   background-color: #4b68ae;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col3, #T_3fc13_row0_col11, #T_3fc13_row1_col23, #T_3fc13_row1_col29, #T_3fc13_row3_col32, #T_3fc13_row4_col22, #T_3fc13_row4_col38, #T_3fc13_row5_col23, #T_3fc13_row6_col35, #T_3fc13_row7_col38 {
#   background-color: #4175b4;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col4, #T_3fc13_row2_col3, #T_3fc13_row2_col12, #T_3fc13_row2_col34, #T_3fc13_row2_col40, #T_3fc13_row4_col5, #T_3fc13_row4_col9, #T_3fc13_row5_col5, #T_3fc13_row5_col11, #T_3fc13_row6_col5, #T_3fc13_row6_col14, #T_3fc13_row6_col24, #T_3fc13_row6_col36, #T_3fc13_row7_col3 {
#   background-color: #4e63ac;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col5, #T_3fc13_row1_col33, #T_3fc13_row3_col20 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col6 {
#   background-color: #60bba8;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row0_col7, #T_3fc13_row0_col33, #T_3fc13_row2_col21, #T_3fc13_row2_col37, #T_3fc13_row4_col34, #T_3fc13_row4_col36, #T_3fc13_row7_col2 {
#   background-color: #4471b2;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col8, #T_3fc13_row0_col10, #T_3fc13_row0_col25, #T_3fc13_row1_col18, #T_3fc13_row1_col21, #T_3fc13_row1_col22, #T_3fc13_row1_col25, #T_3fc13_row1_col26, #T_3fc13_row2_col8, #T_3fc13_row2_col25, #T_3fc13_row2_col36, #T_3fc13_row3_col8, #T_3fc13_row3_col30, #T_3fc13_row4_col10, #T_3fc13_row4_col40, #T_3fc13_row5_col3, #T_3fc13_row5_col26, #T_3fc13_row7_col8 {
#   background-color: #5c51a3;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col9, #T_3fc13_row0_col23, #T_3fc13_row0_col38, #T_3fc13_row1_col24, #T_3fc13_row1_col34, #T_3fc13_row2_col14, #T_3fc13_row2_col30, #T_3fc13_row2_col32, #T_3fc13_row3_col37, #T_3fc13_row4_col4, #T_3fc13_row4_col29, #T_3fc13_row5_col7, #T_3fc13_row5_col24, #T_3fc13_row6_col12, #T_3fc13_row6_col28, #T_3fc13_row7_col14, #T_3fc13_row7_col27 {
#   background-color: #5061aa;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col13, #T_3fc13_row0_col16, #T_3fc13_row0_col21, #T_3fc13_row1_col13, #T_3fc13_row2_col13, #T_3fc13_row3_col24, #T_3fc13_row4_col31, #T_3fc13_row7_col24, #T_3fc13_row7_col34 {
#   background-color: #358bbc;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col14, #T_3fc13_row0_col18, #T_3fc13_row1_col0, #T_3fc13_row1_col32, #T_3fc13_row3_col14, #T_3fc13_row3_col38, #T_3fc13_row5_col18, #T_3fc13_row6_col29, #T_3fc13_row6_col40, #T_3fc13_row7_col0, #T_3fc13_row7_col35 {
#   background-color: #545ca8;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col15 {
#   background-color: #d6ee9b;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row0_col17, #T_3fc13_row0_col36, #T_3fc13_row1_col35, #T_3fc13_row2_col18, #T_3fc13_row2_col27, #T_3fc13_row4_col17, #T_3fc13_row5_col8, #T_3fc13_row5_col28, #T_3fc13_row5_col29, #T_3fc13_row5_col36 {
#   background-color: #5956a5;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col19, #T_3fc13_row0_col27, #T_3fc13_row0_col40, #T_3fc13_row4_col19, #T_3fc13_row4_col23, #T_3fc13_row5_col30, #T_3fc13_row7_col30 {
#   background-color: #5758a6;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col20, #T_3fc13_row0_col22, #T_3fc13_row4_col21, #T_3fc13_row6_col18, #T_3fc13_row7_col1 {
#   background-color: #3d79b6;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col24, #T_3fc13_row1_col4, #T_3fc13_row1_col20, #T_3fc13_row1_col37, #T_3fc13_row1_col40, #T_3fc13_row2_col2, #T_3fc13_row2_col7, #T_3fc13_row2_col23, #T_3fc13_row4_col11, #T_3fc13_row5_col4, #T_3fc13_row5_col14, #T_3fc13_row7_col5, #T_3fc13_row7_col22, #T_3fc13_row7_col23, #T_3fc13_row7_col37 {
#   background-color: #486cb0;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col26, #T_3fc13_row3_col13 {
#   background-color: #74c7a5;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row0_col28, #T_3fc13_row2_col9, #T_3fc13_row3_col17, #T_3fc13_row6_col9, #T_3fc13_row7_col17 {
#   background-color: #3387bc;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col30, #T_3fc13_row1_col2, #T_3fc13_row1_col11, #T_3fc13_row2_col28, #T_3fc13_row2_col29, #T_3fc13_row3_col40, #T_3fc13_row4_col7, #T_3fc13_row4_col28, #T_3fc13_row5_col34, #T_3fc13_row5_col37, #T_3fc13_row6_col34 {
#   background-color: #466eb1;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col31, #T_3fc13_row0_col37, #T_3fc13_row2_col11, #T_3fc13_row2_col20, #T_3fc13_row3_col9, #T_3fc13_row3_col31, #T_3fc13_row5_col2, #T_3fc13_row6_col31, #T_3fc13_row7_col6, #T_3fc13_row7_col9 {
#   background-color: #4273b3;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col34, #T_3fc13_row1_col5, #T_3fc13_row1_col14, #T_3fc13_row2_col22, #T_3fc13_row2_col24, #T_3fc13_row3_col3, #T_3fc13_row3_col4, #T_3fc13_row3_col27, #T_3fc13_row4_col12, #T_3fc13_row5_col35, #T_3fc13_row6_col21, #T_3fc13_row7_col12 {
#   background-color: #4d65ad;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col35, #T_3fc13_row1_col7, #T_3fc13_row3_col2, #T_3fc13_row3_col6, #T_3fc13_row3_col12, #T_3fc13_row3_col25, #T_3fc13_row4_col3, #T_3fc13_row5_col40, #T_3fc13_row6_col2, #T_3fc13_row6_col38, #T_3fc13_row7_col4, #T_3fc13_row7_col40 {
#   background-color: #496aaf;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row0_col39 {
#   background-color: #d3ed9c;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row0_col41, #T_3fc13_row1_col1, #T_3fc13_row1_col3, #T_3fc13_row1_col10, #T_3fc13_row1_col36, #T_3fc13_row1_col39, #T_3fc13_row2_col10, #T_3fc13_row3_col10, #T_3fc13_row4_col25, #T_3fc13_row4_col27, #T_3fc13_row5_col1, #T_3fc13_row5_col10, #T_3fc13_row5_col21, #T_3fc13_row5_col25, #T_3fc13_row5_col27, #T_3fc13_row5_col39, #T_3fc13_row6_col10, #T_3fc13_row6_col25, #T_3fc13_row6_col27, #T_3fc13_row7_col10 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row1_col6 {
#   background-color: #f1f9a9;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row1_col8, #T_3fc13_row1_col27, #T_3fc13_row1_col28, #T_3fc13_row1_col30, #T_3fc13_row1_col38, #T_3fc13_row4_col8, #T_3fc13_row6_col8 {
#   background-color: #5b53a4;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row1_col9, #T_3fc13_row5_col9, #T_3fc13_row5_col16 {
#   background-color: #4ea7b0;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row1_col12, #T_3fc13_row2_col35, #T_3fc13_row3_col1, #T_3fc13_row3_col29, #T_3fc13_row3_col35, #T_3fc13_row4_col2, #T_3fc13_row5_col0, #T_3fc13_row5_col12, #T_3fc13_row6_col3 {
#   background-color: #525fa9;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row1_col15, #T_3fc13_row5_col32, #T_3fc13_row6_col13 {
#   background-color: #6ec5a5;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row1_col16, #T_3fc13_row3_col36 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row1_col17, #T_3fc13_row2_col16, #T_3fc13_row2_col26, #T_3fc13_row3_col5, #T_3fc13_row5_col17, #T_3fc13_row7_col32 {
#   background-color: #3f97b7;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row1_col19 {
#   background-color: #fffab6;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row1_col31, #T_3fc13_row2_col38, #T_3fc13_row3_col0, #T_3fc13_row4_col14, #T_3fc13_row5_col22, #T_3fc13_row5_col31, #T_3fc13_row5_col38, #T_3fc13_row7_col25 {
#   background-color: #555aa7;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row1_col41, #T_3fc13_row6_col30 {
#   background-color: #4ba4b1;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row2_col0, #T_3fc13_row6_col15 {
#   background-color: #bae3a1;
#   color: #000000;
#   width: 3px;
# }
# #T_3fc13_row2_col1, #T_3fc13_row4_col1, #T_3fc13_row6_col33, #T_3fc13_row7_col20 {
#   background-color: #459eb4;
#   color: #f1f1f1;
#   width: 3px;
# }
# #T_3fc13_row2_col5, #T_3fc13_row4_col33, #T_3fc13_row7_col11 {
#   backgro

# %%
ltx_code = ltx_code_o.replace("100.0", "100").replace("\n & 0 \\\\\n\\midrule", "")
replacements = [["ChopperCommand", "ChopperC."], ["SpaceInvaders", "SpaceInv."], ["MontezumaRevenge", "MontezumaR."], ["\\midrule", ""],
               ["\\bottomrule", ""], ["\\toprule", ""], ["Random", "\\rotatebox{90}{Random}"], ["DQN", "\\rotatebox{90}{DQN}"], 
               ["\centering", "\centering \n \setlength{\\tabcolsep}{3pt}"], ["\\cline{1-44}", "",], ["rrrrrrrrrr}", "rrrrrrrrr||c}"],
               ["precision", "Prec."], ["recall", "Rec."], ["f-score", "F1"], ["iou", "IOU"], 
                ["{\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  \\", "{\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1} 100 \\"], 
                ["{\cellcolor[HTML]{9E0142}} \color[HTML]{F1F1F1}  \\", "{\cellcolor[HTML]{9E0142}} \color[HTML]{F1F1F1} 0 \\"],
               ["{\cellcolor[HTML]{EEF8A4}} \color[HTML]{000000}  \\\\",  "{\cellcolor[HTML]{EEF8A4}} \color[HTML]{000000}  \\\\ \cline{1-" + str(nb_games) + "}"] ]
for rpl in replacements: 
    ltx_code = ltx_code.replace(*rpl)

# %%
print(ltx_code)
# Out:
# \begin{table}
# \centering
#  \setlength{\tabcolsep}{3pt}
# \caption{Statistiques on all games}
# \begin{tabular}{llrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr||c}
#
#  &  & \rotatebox{90}{Alien} & \rotatebox{90}{Amidar} & \rotatebox{90}{Assault} & \rotatebox{90}{Asterix} & \rotatebox{90}{Atlantis} & \rotatebox{90}{BankHeist} & \rotatebox{90}{BattleZone} & \rotatebox{90}{Berzerk} & \rotatebox{90}{Bowling} & \rotatebox{90}{Boxing} & \rotatebox{90}{Breakout} & \rotatebox{90}{Carnival} & \rotatebox{90}{Centipede} & \rotatebox{90}{ChopperC.} & \rotatebox{90}{CrazyClimber} & \rotatebox{90}{DemonAttack} & \rotatebox{90}{FishingDerby} & \rotatebox{90}{Freeway} & \rotatebox{90}{Frostbite} & \rotatebox{90}{Gopher} & \rotatebox{90}{Hero} & \rotatebox{90}{IceHockey} & \rotatebox{90}{Jamesbond} & \rotatebox{90}{Kangaroo} & \rotatebox{90}{Krull} & \rotatebox{90}{MontezumaR.} & \rotatebox{90}{MsPacman} & \rotatebox{90}{Pitfall} & \rotatebox{90}{Pong} & \rotatebox{90}{PrivateEye} & \rotatebox{90}{Qbert} & \rotatebox{90}{Riverraid} & \rotatebox{90}{RoadRunner} & \rotatebox{90}{Seaquest} & \rotatebox{90}{Skiing} & \rotatebox{90}{SpaceInv.} & \rotatebox{90}{Tennis} & \rotatebox{90}{TimePilot} & \rotatebox{90}{UpNDown} & \rotatebox{90}{Venture} & \rotatebox{90}{VideoPinball} & \rotatebox{90}{Scale (\%)} \\
#
# \multirow[c]{4}{*}{\rotatebox{90}{Random}} & Prec. & {\cellcolor[HTML]{FCFEBA}} \color[HTML]{000000}  & {\cellcolor[HTML]{81CDA5}} \color[HTML]{000000}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3B92B9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{60BBA8}} \color[HTML]{000000}  & {\cellcolor[HTML]{4471B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{D6EE9B}} \color[HTML]{000000}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5758A6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3D79B6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3D79B6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{74C7A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{5758A6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3387BC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4471B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{D3ED9C}} \color[HTML]{000000}  & {\cellcolor[HTML]{5758A6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1} 100 \\
#  & Rec. & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{F1F9A9}} \color[HTML]{000000}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5B53A4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4EA7B0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{6EC5A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{47A0B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F97B7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{FFFAB6}} \color[HTML]{000000}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5B53A4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5B53A4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5B53A4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3B92B9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5B53A4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4BA4B1}} \color[HTML]{F1F1F1}  \\
#  & F1 & {\cellcolor[HTML]{BAE3A1}} \color[HTML]{000000}  & {\cellcolor[HTML]{459EB4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3A7EB8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{C3E79F}} \color[HTML]{000000}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3387BC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{ACDDA4}} \color[HTML]{000000}  & {\cellcolor[HTML]{3F97B7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F77B5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{CAEA9E}} \color[HTML]{000000}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4471B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F97B7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3682BA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4471B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{76C8A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{AADCA4}} \color[HTML]{000000}  \\
#  & IOU & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F97B7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{71C6A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3682BA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{74C7A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{66C2A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{86CFA5}} \color[HTML]{000000}  & {\cellcolor[HTML]{3387BC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F77B5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{71C6A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{3B92B9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{C1E6A0}} \color[HTML]{000000}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{50A9AF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5CB7AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3585BB}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3585BB}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{47A0B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3B7CB7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{EEF8A4}} \color[HTML]{000000}  \\ \cline{1-41}
#
# \multirow[c]{4}{*}{\rotatebox{90}{DQN}} & Prec. & {\cellcolor[HTML]{FCFEBA}} \color[HTML]{000000}  & {\cellcolor[HTML]{459EB4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5CB7AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5B53A4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{71C6A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{E7F59A}} \color[HTML]{000000}  & {\cellcolor[HTML]{378EBB}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3D95B8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5758A6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{6BC4A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{3D79B6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5758A6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{9CD7A4}} \color[HTML]{000000}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{89D0A4}} \color[HTML]{000000}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{49A2B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3A7EB8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4471B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3585BB}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4471B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3880B9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{ECF7A1}} \color[HTML]{000000}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{FEEA9B}} \color[HTML]{000000}  \\
#  & Rec. & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{FBFDB8}} \color[HTML]{000000}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4EA7B0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{69C3A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{76C8A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{4EA7B0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F97B7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{FFF7B2}} \color[HTML]{000000}  & {\cellcolor[HTML]{3990BA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5758A6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{6EC5A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{5EB9A9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5956A5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{FBA05B}} \color[HTML]{000000}  \\
#  & F1 & {\cellcolor[HTML]{BCE4A0}} \color[HTML]{000000}  & {\cellcolor[HTML]{3F77B5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{525FA9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{D1ED9C}} \color[HTML]{000000}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5B53A4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3387BC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{6EC5A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{BAE3A1}} \color[HTML]{000000}  & {\cellcolor[HTML]{439BB5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F77B5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3D79B6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{CDEB9D}} \color[HTML]{000000}  & {\cellcolor[HTML]{54AEAD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{52ABAE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4BA4B1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5CB7AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{459EB4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{466EB1}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F77B5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{94D4A4}} \color[HTML]{000000}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{E1504B}} \color[HTML]{F1F1F1}  \\
#  & IOU & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3D79B6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4471B2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4E63AC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{76C8A5}} \color[HTML]{000000}  & {\cellcolor[HTML]{5C51A3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4273B3}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5E4FA2}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3A7EB8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4D65AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{439BB5}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{50A9AF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{91D3A4}} \color[HTML]{000000}  & {\cellcolor[HTML]{3387BC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4199B6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{50A9AF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{459EB4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{C1E6A0}} \color[HTML]{000000}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{555AA7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{56B0AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5061AA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{56B0AD}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4B68AE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{5758A6}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3682BA}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3F97B7}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3880B9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{358BBC}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{545CA8}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{52ABAE}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{486CB0}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{4175B4}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{3880B9}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{496AAF}} \color[HTML]{F1F1F1}  & {\cellcolor[HTML]{9E0142}} \color[HTML]{F1F1F1} 0 \\
#
#
# \end{tabular}
# \end{table}

# %%
with open(latex_report_file, 'w') as texfile:
    texfile.write(ltx_code)
